# %% [markdown]
# # Data Description

# %% [markdown]
# MSSubClass: Identifies the type of dwelling involved in the sale.
#
#
#         20	1-STORY 1946 & NEWER ALL STYLES
#         30	1-STORY 1945 & OLDER
#         40	1-STORY W/FINISHED ATTIC ALL AGES
#         45	1-1/2 STORY - UNFINISHED ALL AGES
#         50	1-1/2 STORY FINISHED ALL AGES
#         60	2-STORY 1946 & NEWER
#         70	2-STORY 1945 & OLDER
#         75	2-1/2 STORY ALL AGES
#         80	SPLIT OR MULTI-LEVEL
#         85	SPLIT FOYER
#         90	DUPLEX - ALL STYLES AND AGES
#        120	1-STORY PUD (Planned Unit Development) - 1946 & NEWER
#        150	1-1/2 STORY PUD - ALL AGES
#        160	2-STORY PUD - 1946 & NEWER
#        180	PUD - MULTILEVEL - INCL SPLIT LEV/FOYER
#        190	2 FAMILY CONVERSION - ALL STYLES AND AGES
#
# MSZoning: Identifies the general zoning classification of the sale.
#
#        A	Agriculture
#        C	Commercial
#        FV	Floating Village Residential
#        I	Industrial
#        RH	Residential High Density
#        RL	Residential Low Density
#        RP	Residential Low Density Park
#        RM	Residential Medium Density
#
# LotFrontage: Linear feet of street connected to property
#
# LotArea: Lot size in square feet
#
# Street: Type of road access to property
#
#        Grvl	Gravel
#        Pave	Paved
#
# Alley: Type of alley access to property
#
#        Grvl	Gravel
#        Pave	Paved
#        NA 	No alley access
#
# LotShape: General shape of property
#
#        Reg	Regular
#        IR1	Slightly irregular
#        IR2	Moderately Irregular
#        IR3	Irregular
#
# LandContour: Flatness of the property
#
#        Lvl	Near Flat/Level
#        Bnk	Banked - Quick and significant rise from street grade to building
#        HLS	Hillside - Significant slope from side to side
#        Low	Depression
#
# Utilities: Type of utilities available
#
#        AllPub	All public Utilities (E,G,W,& S)
#        NoSewr	Electricity, Gas, and Water (Septic Tank)
#        NoSeWa	Electricity and Gas Only
#        ELO	Electricity only
#
# LotConfig: Lot configuration
#
#        Inside	Inside lot
#        Corner	Corner lot
#        CulDSac	Cul-de-sac
#        FR2	Frontage on 2 sides of property
#        FR3	Frontage on 3 sides of property
#
# LandSlope: Slope of property
#
#        Gtl	Gentle slope
#        Mod	Moderate Slope
#        Sev	Severe Slope
#
# Neighborhood: Physical locations within Ames city limits
#
#        Blmngtn	Bloomington Heights
#        Blueste	Bluestem
#        BrDale	Briardale
#        BrkSide	Brookside
#        ClearCr	Clear Creek
#        CollgCr	College Creek
#        Crawfor	Crawford
#        Edwards	Edwards
#        Gilbert	Gilbert
#        IDOTRR	Iowa DOT and Rail Road
#        MeadowV	Meadow Village
#        Mitchel	Mitchell
#        Names	North Ames
#        NoRidge	Northridge
#        NPkVill	Northpark Villa
#        NridgHt	Northridge Heights
#        NWAmes	Northwest Ames
#        OldTown	Old Town
#        SWISU	South & West of Iowa State University
#        Sawyer	Sawyer
#        SawyerW	Sawyer West
#        Somerst	Somerset
#        StoneBr	Stone Brook
#        Timber	Timberland
#        Veenker	Veenker
#
# Condition1: Proximity to various conditions
#
#        Artery	Adjacent to arterial street
#        Feedr	Adjacent to feeder street
#        Norm	Normal
#        RRNn	Within 200' of North-South Railroad
#        RRAn	Adjacent to North-South Railroad
#        PosN	Near positive off-site feature--park, greenbelt, etc.
#        PosA	Adjacent to postive off-site feature
#        RRNe	Within 200' of East-West Railroad
#        RRAe	Adjacent to East-West Railroad
#
# Condition2: Proximity to various conditions (if more than one is present)
#
#        Artery	Adjacent to arterial street
#        Feedr	Adjacent to feeder street
#        Norm	Normal
#        RRNn	Within 200' of North-South Railroad
#        RRAn	Adjacent to North-South Railroad
#        PosN	Near positive off-site feature--park, greenbelt, etc.
#        PosA	Adjacent to postive off-site feature
#        RRNe	Within 200' of East-West Railroad
#        RRAe	Adjacent to East-West Railroad
#
# BldgType: Type of dwelling
#
#        1Fam	Single-family Detached
#        2FmCon	Two-family Conversion; originally built as one-family dwelling
#        Duplx	Duplex
#        TwnhsE	Townhouse End Unit
#        TwnhsI	Townhouse Inside Unit
#
# HouseStyle: Style of dwelling
#
#        1Story	One story
#        1.5Fin	One and one-half story: 2nd level finished
#        1.5Unf	One and one-half story: 2nd level unfinished
#        2Story	Two story
#        2.5Fin	Two and one-half story: 2nd level finished
#        2.5Unf	Two and one-half story: 2nd level unfinished
#        SFoyer	Split Foyer
#        SLvl	Split Level
#
# OverallQual: Rates the overall material and finish of the house
#
#        10	Very Excellent
#        9	Excellent
#        8	Very Good
#        7	Good
#        6	Above Average
#        5	Average
#        4	Below Average
#        3	Fair
#        2	Poor
#        1	Very Poor
#
# OverallCond: Rates the overall condition of the house
#
#        10	Very Excellent
#        9	Excellent
#        8	Very Good
#        7	Good
#        6	Above Average
#        5	Average
#        4	Below Average
#        3	Fair
#        2	Poor
#        1	Very Poor
#
# YearBuilt: Original construction date
#
# YearRemodAdd: Remodel date (same as construction date if no remodeling or additions)
#
# RoofStyle: Type of roof
#
#        Flat	Flat
#        Gable	Gable
#        Gambrel	Gabrel (Barn)
#        Hip	Hip
#        Mansard	Mansard
#        Shed	Shed
#
# RoofMatl: Roof material
#
#        ClyTile	Clay or Tile
#        CompShg	Standard (Composite) Shingle
#        Membran	Membrane
#        Metal	Metal
#        Roll	Roll
#        Tar&Grv	Gravel & Tar
#        WdShake	Wood Shakes
#        WdShngl	Wood Shingles
#
# Exterior1st: Exterior covering on house
#
#        AsbShng	Asbestos Shingles
#        AsphShn	Asphalt Shingles
#        BrkComm	Brick Common
#        BrkFace	Brick Face
#        CBlock	Cinder Block
#        CemntBd	Cement Board
#        HdBoard	Hard Board
#        ImStucc	Imitation Stucco
#        MetalSd	Metal Siding
#        Other	Other
#        Plywood	Plywood
#        PreCast	PreCast
#        Stone	Stone
#        Stucco	Stucco
#        VinylSd	Vinyl Siding
#        Wd Sdng	Wood Siding
#        WdShing	Wood Shingles
#
# Exterior2nd: Exterior covering on house (if more than one material)
#
#        AsbShng	Asbestos Shingles
#        AsphShn	Asphalt Shingles
#        BrkComm	Brick Common
#        BrkFace	Brick Face
#        CBlock	Cinder Block
#        CemntBd	Cement Board
#        HdBoard	Hard Board
#        ImStucc	Imitation Stucco
#        MetalSd	Metal Siding
#        Other	Other
#        Plywood	Plywood
#        PreCast	PreCast
#        Stone	Stone
#        Stucco	Stucco
#        VinylSd	Vinyl Siding
#        Wd Sdng	Wood Siding
#        WdShing	Wood Shingles
#
# MasVnrType: Masonry veneer type
#
#        BrkCmn	Brick Common
#        BrkFace	Brick Face
#        CBlock	Cinder Block
#        None	None
#        Stone	Stone
#
# MasVnrArea: Masonry veneer area in square feet
#
# ExterQual: Evaluates the quality of the material on the exterior
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        Po	Poor
#
# ExterCond: Evaluates the present condition of the material on the exterior
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        Po	Poor
#
# Foundation: Type of foundation
#
#        BrkTil	Brick & Tile
#        CBlock	Cinder Block
#        PConc	Poured Contrete
#        Slab	Slab
#        Stone	Stone
#        Wood	Wood
#
# BsmtQual: Evaluates the height of the basement
#
#        Ex	Excellent (100+ inches)
#        Gd	Good (90-99 inches)
#        TA	Typical (80-89 inches)
#        Fa	Fair (70-79 inches)
#        Po	Poor (<70 inches
#        NA	No Basement
#
# BsmtCond: Evaluates the general condition of the basement
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical - slight dampness allowed
#        Fa	Fair - dampness or some cracking or settling
#        Po	Poor - Severe cracking, settling, or wetness
#        NA	No Basement
#
# BsmtExposure: Refers to walkout or garden level walls
#
#        Gd	Good Exposure
#        Av	Average Exposure (split levels or foyers typically score average or above)
#        Mn	Mimimum Exposure
#        No	No Exposure
#        NA	No Basement
#
# BsmtFinType1: Rating of basement finished area
#
#        GLQ	Good Living Quarters
#        ALQ	Average Living Quarters
#        BLQ	Below Average Living Quarters
#        Rec	Average Rec Room
#        LwQ	Low Quality
#        Unf	Unfinshed
#        NA	No Basement
#
# BsmtFinSF1: Type 1 finished square feet
#
# BsmtFinType2: Rating of basement finished area (if multiple types)
#
#        GLQ	Good Living Quarters
#        ALQ	Average Living Quarters
#        BLQ	Below Average Living Quarters
#        Rec	Average Rec Room
#        LwQ	Low Quality
#        Unf	Unfinshed
#        NA	No Basement
#
# BsmtFinSF2: Type 2 finished square feet
#
# BsmtUnfSF: Unfinished square feet of basement area
#
# TotalBsmtSF: Total square feet of basement area
#
# Heating: Type of heating
#
#        Floor	Floor Furnace
#        GasA	Gas forced warm air furnace
#        GasW	Gas hot water or steam heat
#        Grav	Gravity furnace
#        OthW	Hot water or steam heat other than gas
#        Wall	Wall furnace
#
# HeatingQC: Heating quality and condition
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        Po	Poor
#
# CentralAir: Central air conditioning
#
#        N	No
#        Y	Yes
#
# Electrical: Electrical system
#
#        SBrkr	Standard Circuit Breakers & Romex
#        FuseA	Fuse Box over 60 AMP and all Romex wiring (Average)
#        FuseF	60 AMP Fuse Box and mostly Romex wiring (Fair)
#        FuseP	60 AMP Fuse Box and mostly knob & tube wiring (poor)
#        Mix	Mixed
#
# 1stFlrSF: First Floor square feet
#
# 2ndFlrSF: Second floor square feet
#
# LowQualFinSF: Low quality finished square feet (all floors)
#
# GrLivArea: Above grade (ground) living area square feet
#
# BsmtFullBath: Basement full bathrooms
#
# BsmtHalfBath: Basement half bathrooms
#
# FullBath: Full bathrooms above grade
#
# HalfBath: Half baths above grade
#
# Bedroom: Bedrooms above grade (does NOT include basement bedrooms)
#
# Kitchen: Kitchens above grade
#
# KitchenQual: Kitchen quality
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical/Average
#        Fa	Fair
#        Po	Poor
#
# TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)
#
# Functional: Home functionality (Assume typical unless deductions are warranted)
#
#        Typ	Typical Functionality
#        Min1	Minor Deductions 1
#        Min2	Minor Deductions 2
#        Mod	Moderate Deductions
#        Maj1	Major Deductions 1
#        Maj2	Major Deductions 2
#        Sev	Severely Damaged
#        Sal	Salvage only
#
# Fireplaces: Number of fireplaces
#
# FireplaceQu: Fireplace quality
#
#        Ex	Excellent - Exceptional Masonry Fireplace
#        Gd	Good - Masonry Fireplace in main level
#        TA	Average - Prefabricated Fireplace in main living area or Masonry Fireplace in basement
#        Fa	Fair - Prefabricated Fireplace in basement
#        Po	Poor - Ben Franklin Stove
#        NA	No Fireplace
#
# GarageType: Garage location
#
#        2Types	More than one type of garage
#        Attchd	Attached to home
#        Basment	Basement Garage
#        BuiltIn	Built-In (Garage part of house - typically has room above garage)
#        CarPort	Car Port
#        Detchd	Detached from home
#        NA	No Garage
#
# GarageYrBlt: Year garage was built
#
# GarageFinish: Interior finish of the garage
#
#        Fin	Finished
#        RFn	Rough Finished
#        Unf	Unfinished
#        NA	No Garage
#
# GarageCars: Size of garage in car capacity
#
# GarageArea: Size of garage in square feet
#
# GarageQual: Garage quality
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical/Average
#        Fa	Fair
#        Po	Poor
#        NA	No Garage
#
# GarageCond: Garage condition
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical/Average
#        Fa	Fair
#        Po	Poor
#        NA	No Garage
#
# PavedDrive: Paved driveway
#
#        Y	Paved
#        P	Partial Pavement
#        N	Dirt/Gravel
#
# WoodDeckSF: Wood deck area in square feet
#
# OpenPorchSF: Open porch area in square feet
#
# EnclosedPorch: Enclosed porch area in square feet
#
# 3SsnPorch: Three season porch area in square feet
#
# ScreenPorch: Screen porch area in square feet
#
# PoolArea: Pool area in square feet
#
# PoolQC: Pool quality
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        NA	No Pool
#
# Fence: Fence quality
#
#        GdPrv	Good Privacy
#        MnPrv	Minimum Privacy
#        GdWo	Good Wood
#        MnWw	Minimum Wood/Wire
#        NA	No Fence
#
# MiscFeature: Miscellaneous feature not covered in other categories
#
#        Elev	Elevator
#        Gar2	2nd Garage (if not described in garage section)
#        Othr	Other
#        Shed	Shed (over 100 SF)
#        TenC	Tennis Court
#        NA	None
#
# MiscVal: $Value of miscellaneous feature
#
# MoSold: Month Sold (MM)
#
# YrSold: Year Sold (YYYY)
#
# SaleType: Type of sale
#
#        WD 	Warranty Deed - Conventional
#        CWD	Warranty Deed - Cash
#        VWD	Warranty Deed - VA Loan
#        New	Home just constructed and sold
#        COD	Court Officer Deed/Estate
#        Con	Contract 15% Down payment regular terms
#        ConLw	Contract Low Down payment and low interest
#        ConLI	Contract Low Interest
#        ConLD	Contract Low Down
#        Oth	Other
#
# SaleCondition: Condition of sale
#
#        Normal	Normal Sale
#        Abnorml	Abnormal Sale -  trade, foreclosure, short sale
#        AdjLand	Adjoining Land Purchase
#        Alloca	Allocation - two linked properties with separate deeds, typically condo with a garage unit
#        Family	Sale between family members
#        Partial	Home was not completed when last assessed (associated with New Homes)

# %% [markdown]
# # Import Basic toools

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Get train Data

# %%
df=pd.read_csv('/content/drive/MyDrive/Kaggle Competition/Regression/House Price/train.csv')
print(f'Data contains {df.shape[0]} rows and {df.shape[1]} columns')
df.head()
# Out:
# Data contains 1460 rows and 81 columns
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %% [markdown]
# # Preprocessing or cleaning data

# %% [markdown]
# ## Split data into features and label

# %%
# first check whether there is any na in label column
df['SalePrice'].isna().sum()
# Out:
# 0

# %%
# Split feature columns as x and also drop Id column
x=df.drop(['Id','SalePrice'],axis=1)

# Label column as y
y=df['SalePrice']

# %%
# Let's check the x and y 
print(f'shape of features or x is:{x.shape} and shape of Label or y is: {y.shape}\n')
print('First five data from x\n')
print(x.head())
print('First five data from y\n')
print(y.head())
# Out:
# shape of features or x is:(1460, 79) and shape of Label or y is: (1460,)
#
# First five data from x
#
#    MSSubClass MSZoning  LotFrontage  ...  YrSold SaleType SaleCondition
# 0          60       RL         65.0  ...    2008       WD        Normal
# 1          20       RL         80.0  ...    2007       WD        Normal
# 2          60       RL         68.0  ...    2008       WD        Normal
# 3          70       RL         60.0  ...    2006       WD       Abnorml
# 4          60       RL         84.0  ...    2008       WD        Normal
#
# [5 rows x 79 columns]
# First five data from y
#
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# Name: SalePrice, dtype: int64

# %% [markdown]
# ## Info of Feature DataFrame

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 79 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %% [markdown]
# ## Describe feature DataFrame

# %%
x.describe()
# Out:
#         MSSubClass  LotFrontage  ...       MoSold       YrSold
# count  1460.000000  1201.000000  ...  1460.000000  1460.000000
# mean     56.897260    70.049958  ...     6.321918  2007.815753
# std      42.300571    24.284752  ...     2.703626     1.328095
# min      20.000000    21.000000  ...     1.000000  2006.000000
# 25%      20.000000    59.000000  ...     5.000000  2007.000000
# 50%      50.000000    69.000000  ...     6.000000  2008.000000
# 75%      70.000000    80.000000  ...     8.000000  2009.000000
# max     190.000000   313.000000  ...    12.000000  2010.000000
#
# [8 rows x 36 columns]

# %% [markdown]
# ## Check for missing values in X

# %%
plt.figure(figsize=(20,10))
x.isna().sum().sort_values(ascending=False).plot(kind='bar')
plt.tight_layout()
plt.show();

# %%
# Check for type
type(x.isna().sum())
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Filling the Missing values

# %% [markdown]
# ### filling object columns

# %%
na_columns=x.isna().sum()

# List of String(Object) columns
categorical_column=[]
for column_name,column_value in x.items():
  if pd.api.types.is_string_dtype(column_value):
    categorical_column.append(column_name)
# Fill na only for String Columns
for k,v in na_columns.items():
  if (k in categorical_column) & (v>0):
    x[k]=x[k].fillna('no')

# %%
# Let's check for na columns
x.isna().sum().sort_values(ascending=False)
# Out:
# LotFrontage     259
# GarageYrBlt      81
# MasVnrArea        8
# Foundation        0
# RoofMatl          0
#                ...
# KitchenQual       0
# TotRmsAbvGrd      0
# Functional        0
# Fireplaces        0
# MSSubClass        0
# Length: 79, dtype: int64

# %% [markdown]
# ### Changing the type from object to categorical

# %%
for column_name,column_values in x.items():
  if pd.api.types.is_string_dtype(column_values):
    x[column_name]=column_value.astype('category').cat.as_ordered()

# %%
# Check whether object column is converted into categorical
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 79 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   category
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   category
#  5   Alley          1460 non-null   category
#  6   LotShape       1460 non-null   category
#  7   LandContour    1460 non-null   category
#  8   Utilities      1460 non-null   category
#  9   LotConfig      1460 non-null   category
#  10  LandSlope      1460 non-null   category
#  11  Neighborhood   1460 non-null   category
#  12  Condition1     1460 non-null   category
#  13  Condition2     1460 non-null   category
#  14  BldgType       1460 non-null   category
#  15  HouseStyle     1460 non-null   category
#  16  OverallQual    1460 non-null   int64
# ...

# %% [markdown]
# ### Encoding all the categorical values

# %%
for column_name,column_values in x.items():
  if not pd.api.types.is_numeric_dtype(column_values):
    x[column_name]=pd.Categorical(column_values).codes+1

# %%
# Check for first five column values of x
x.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage  ...  YrSold  SaleType  SaleCondition
# 0          60         5         65.0  ...    2008         5              5
# 1          20         5         80.0  ...    2007         5              5
# 2          60         5         68.0  ...    2008         5              5
# 3          70         1         60.0  ...    2006         1              1
# 4          60         5         84.0  ...    2008         5              5
#
# [5 rows x 79 columns]

# %% [markdown]
# ### Fillup all the remaining numeric column missing values using iterativeImputer Method

# %%
# import the tools
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
imputer=IterativeImputer(random_state=0,sample_posterior=False,max_iter=1,min_value=0)
imputer.fit(x)
# Out:
# IterativeImputer(add_indicator=False, estimator=None,
#                  imputation_order='ascending', initial_strategy='mean',
#                  max_iter=1, max_value=None, min_value=0, missing_values=nan,
#                  n_nearest_features=None, random_state=0,
#                  sample_posterior=False, skip_complete=False, tol=0.001,
#                  verbose=0)

# %%
# Let's create back our dataFrame with all the filled values
x=pd.DataFrame(imputer.transform(x),columns=x.columns)

#Let's see first five 
x.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage  ...  YrSold  SaleType  SaleCondition
# 0        60.0       5.0         65.0  ...  2008.0       5.0            5.0
# 1        20.0       5.0         80.0  ...  2007.0       5.0            5.0
# 2        60.0       5.0         68.0  ...  2008.0       5.0            5.0
# 3        70.0       1.0         60.0  ...  2006.0       1.0            1.0
# 4        60.0       5.0         84.0  ...  2008.0       5.0            5.0
#
# [5 rows x 79 columns]

# %% [markdown]
# ## Finding top 20 best feature column for training our Model

# %% [markdown]
# ### Using SelectKBest Method

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression

# %%
bestfeatures = SelectKBest(score_func=f_regression, k=20)
fit = bestfeatures.fit(x,y)

# %%
dfscores = pd.DataFrame({'features':x.columns,'Scores':fit.scores_})
dfscores=dfscores.sort_values(by='Scores',ascending=False)

# %%
dfscores.head()
# Out:
#        features       Scores
# 16  OverallQual  2436.770591
# 45    GrLivArea  1470.585010
# 60   GarageCars  1013.705666
# 61   GarageArea   926.951287
# 37  TotalBsmtSF   880.341282

# %%
print(dfscores.nlargest(20,'Scores'))  #print 20 best features
# Out:
#         features       Scores
# 16   OverallQual  2436.770591
# 45     GrLivArea  1470.585010
# 60    GarageCars  1013.705666
# 61    GarageArea   926.951287
# 37   TotalBsmtSF   880.341282
# 42      1stFlrSF   845.524488
# 48      FullBath   668.430296
# 53  TotRmsAbvGrd   580.762801
# 18     YearBuilt   548.665821
# 58   GarageYrBlt   537.317884
# 19  YearRemodAdd   504.714855
# 25    MasVnrArea   431.402480
# 55    Fireplaces   406.503866
# 33    BsmtFinSF1   255.923517
# 2    LotFrontage   228.865738
# 65    WoodDeckSF   171.494673
# 43      2ndFlrSF   165.561151
# 66   OpenPorchSF   161.577391
# 49      HalfBath   128.018964
# 3        LotArea   109.090355

# %%
plt.figure(figsize=(20,30))
dfscores.nlargest(11,'Scores').plot(kind='barh')
plt.tight_layout();

# %% [markdown]
# ### Using ExtraTreesClassifier

# %%
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model = ExtraTreesClassifier()
model.fit(x,y)
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100,
#                      n_jobs=None, oob_score=False, random_state=None, verbose=0,
#                      warm_start=False)

# %%
plt.figure(figsize=(10,20))
feat_importances = pd.DataFrame({'features':x.columns,'Scores':model.feature_importances_})
feat_importances.nlargest(10,'Scores').plot(x='features',kind='barh')
plt.show()

# %% [markdown]
# ### Comparing or Selecting the Common features from SelectKBest and ExtraTreeClassifier output

# %%
tree_20_best=feat_importances.sort_values(by='Scores',ascending=False).head(20)
k_best=dfscores.head(20)

best_feature=[]
for i in k_best['features']:
  for j in tree_20_best['features']:
    if i==j:
      best_feature.append(i)

# %%
print(len(best_feature))
print(best_feature)
# Out:
# 16
# ['OverallQual', 'GrLivArea', 'GarageArea', 'TotalBsmtSF', '1stFlrSF', 'TotRmsAbvGrd', 'YearBuilt', 'GarageYrBlt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'LotFrontage', 'WoodDeckSF', '2ndFlrSF', 'OpenPorchSF', 'LotArea']

# %% [markdown]
# ### Filtering all the unnecessary columns from DataFrame

# %%
final_dataframe=pd.DataFrame()
for i in best_feature:
  final_dataframe[best_feature]=x[best_feature]

# %%
final_dataframe
# Out:
#       OverallQual  GrLivArea  GarageArea  ...  2ndFlrSF  OpenPorchSF  LotArea
# 0             7.0     1710.0       548.0  ...     854.0         61.0   8450.0
# 1             6.0     1262.0       460.0  ...       0.0          0.0   9600.0
# 2             7.0     1786.0       608.0  ...     866.0         42.0  11250.0
# 3             7.0     1717.0       642.0  ...     756.0         35.0   9550.0
# 4             8.0     2198.0       836.0  ...    1053.0         84.0  14260.0
# ...           ...        ...         ...  ...       ...          ...      ...
# 1455          6.0     1647.0       460.0  ...     694.0         40.0   7917.0
# 1456          6.0     2073.0       500.0  ...       0.0          0.0  13175.0
# 1457          7.0     2340.0       252.0  ...    1152.0         60.0   9042.0
# 1458          5.0     1078.0       240.0  ...       0.0          0.0   9717.0
# 1459          5.0     1256.0       276.0  ...       0.0         68.0   9937.0
#
# [1460 rows x 16 columns]

# %% [markdown]
# # Split dataset into train and test

# %%
from sklearn.model_selection import train_test_split
x_train,x_val,y_train,y_val=train_test_split(final_dataframe,y,test_size=0.2)

# %% [markdown]
# # Let's Build a Regression Model

# %% [markdown]
# ## Linear Model

# %%
from sklearn.linear_model import LinearRegression
np.random.seed(20)

linear_model=LinearRegression()
linear_model.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
linear_score=linear_model.score(x_val,y_val)
linear_score
# Out:
# 0.8035154090076

# %% [markdown]
# ## SVR

# %%
from sklearn.svm import SVR
np.random.seed(23)
svr_model=SVR()
svr_model.fit(x_train,y_train)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
svr_score=svr_model.score(x_val,y_val)
svr_score
# Out:
# -0.038840846999530276

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor
np.random.seed(24)

tree_model=DecisionTreeRegressor()
tree_model.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
tree_score=tree_model.score(x_val,y_val)
tree_score
# Out:
# 0.7816854954573242

# %% [markdown]
# ## Random Forest Model

# %%
from sklearn.ensemble import RandomForestRegressor

np.random.seed(25)

random_model=RandomForestRegressor()
random_model.fit(x_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
random_score=random_model.score(x_val,y_val)
random_score
# Out:
# 0.872348967175072

# %% [markdown]
# ## XG Boost

# %%
from xgboost import XGBRegressor
np.random.seed(26)
xg_model=XGBRegressor()
xg_model.fit(x_train,y_train)
# Out:
# [06:20:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
xg_score=xg_model.score(x_val,y_val)
xg_score
# Out:
# 0.8788794728975227

# %%
# with Standard Scaler

from sklearn.preprocessing import StandardScaler
std=StandardScaler()
x_std_train=std.fit_transform(x_train)
x_std_val=std.transform(x_val)

# %%
np.random.seed(28)
xg_std_model=XGBRegressor()
xg_std_model.fit(x_std_train,y_train)
# Out:
# [06:23:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
xg_std_score=xg_std_model.score(x_std_val,y_val)
xg_std_score
# Out:
# 0.8779774639443286

# %% [markdown]
# ## Find which model performed best

# %%
best_model=pd.DataFrame(data={'model':['Linear','SVM','Decision Tree','RandomForest','XGBoost'],'score':[linear_score,svr_score,tree_score,random_score,xg_score]})
best_model.sort_values(by='score',ascending=False)
# Out:
#            model     score
# 4        XGBoost  0.878879
# 3   RandomForest  0.872349
# 0         Linear  0.803515
# 2  Decision Tree  0.781685
# 1            SVM -0.038841

# %% [markdown]
# # HyperParameter Tuning

# %% [markdown]
# ## GridSearchCV

# %% [markdown]
# Note: Since the score of XGBoost and Random Forest model are almost nearby. So we will perform Parameter Tuning for both

# %% [markdown]
# Using GridSearchCV on Random Forest

# %%
from sklearn.model_selection import GridSearchCV
np.random.seed(50)

parameters={'n_estimators':[100,125,150,175,200,250,300,500],
            'max_depth':[None,1,2,3,4,5,10,20,30],
            'max_features':['auto','sqrt'],
            'min_samples_split':[2,4,6,8],
            'min_samples_leaf':[1,2,3,4,5,6]}

random_grid=GridSearchCV(estimator=random_model,param_grid=parameters,cv=5,n_jobs=-1,verbose=2,scoring='neg_root_mean_squared_error')

random_grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 3456 candidates, totalling 17280 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:   44.7s
# [Parallel(n_jobs=-1)]: Done 158 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 361 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=-1)]: Done 644 tasks      | elapsed: 10.9min
# [Parallel(n_jobs=-1)]: Done 1009 tasks      | elapsed: 15.9min
# [Parallel(n_jobs=-1)]: Done 1454 tasks      | elapsed: 19.4min
# [Parallel(n_jobs=-1)]: Done 1981 tasks      | elapsed: 23.0min
# [Parallel(n_jobs=-1)]: Done 2588 tasks      | elapsed: 26.3min
# [Parallel(n_jobs=-1)]: Done 3277 tasks      | elapsed: 29.7min
# [Parallel(n_jobs=-1)]: Done 4046 tasks      | elapsed: 33.6min
# [Parallel(n_jobs=-1)]: Done 4897 tasks      | elapsed: 39.3min
# [Parallel(n_jobs=-1)]: Done 5828 tasks      | elapsed: 44.0min
# [Parallel(n_jobs=-1)]: Done 6841 tasks      | elapsed: 52.2min
# ...

# %%
best_random_accuracy=random_grid.best_score_
best_random_params=random_grid.best_params_

print(f'Best Random Forest Accuracy: {best_random_accuracy}')
print(f'Best Ransdom Forest Paramsters: {best_random_params}')
# Out:
# Best Random Forest Accuracy: -30704.249551944977
# Best Ransdom Forest Paramsters: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 150}

# %% [markdown]
# using GridSearchCV on XGBoost

# %%
np.random.seed(75)

xg_parameters={'learning_rate': [0.01, 0.1],
        'max_depth': [3, 5, 7, 10],
        'min_child_weight': [1, 3, 5],
        'subsample': [0.5, 0.7],
        'colsample_bytree': [0.5, 0.7],
        'n_estimators' : [100, 200, 500],
        'objective': ['reg:squarederror']}

xg_grid=GridSearchCV(estimator=xg_model,param_grid=xg_parameters,cv=5,scoring='neg_root_mean_squared_error',n_jobs=-1,verbose=1)

xg_grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 288 candidates, totalling 1440 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=-1)]: Done 196 tasks      | elapsed:   33.7s
# [Parallel(n_jobs=-1)]: Done 446 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 796 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 1246 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=-1)]: Done 1440 out of 1440 | elapsed:  6.3min finished
# GridSearchCV(cv=5, error_score=nan,
#              estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                     colsample_bylevel=1, colsample_bynode=1,
#                                     colsample_bytree=1, gamma=0,
#                                     importance_type='gain', learning_rate=0.1,
#                                     max_delta_step=0, max_depth=3,
# ...

# %%
best_xg_accuracy=xg_grid.best_score_
best_xg_params=xg_grid.best_params_

print(f'Best XG Boost Accuracy: {best_xg_accuracy}')
print(f'Best XG Boost Parameters: {best_xg_params}')
# Out:
# Best XG Boost Accuracy: -28767.023205217447
# Best XG Boost Parameters: {'colsample_bytree': 0.7, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'objective': 'reg:squarederror', 'subsample': 0.5}

# %%
np.random.seed(99)
final_random_model=RandomForestRegressor(max_depth= 20, max_features= 'sqrt', min_samples_leaf= 2, min_samples_split= 2, n_estimators=150)

# %%
final_random_model.fit(x_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=20, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=2,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=150, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
random_y_pred=final_random_model.predict(x_val)

# %%
from sklearn.metrics import mean_squared_error

random_mean_error=mean_squared_error(y_val,random_y_pred)
print(f'Mean Squared error is: {random_mean_error}')
print(f'Sqrt of Mean Squared eroor is: {np.sqrt(random_mean_error)}')
# Out:
# Mean Squared error is: 860558699.8177667
# Sqrt of Mean Squared eroor is: 29335.2808034586

# %%
final_random_model.score(x_val,y_val)
# Out:
# 0.865438817162794

# %%
np.random.seed(102)
final_xg_model=XGBRegressor(**best_xg_params)
final_xg_model.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.7, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=200,
#              n_jobs=1, nthread=None, objective='reg:squarederror',
#              random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#              seed=None, silent=None, subsample=0.5, verbosity=1)

# %%
xg_predict=final_xg_model.predict(x_val)

xg_mean_error=mean_squared_error(y_val,xg_predict)
print(f'Mean Squared error is: {xg_mean_error}')
print(f'Sqrt of Mean Squared eroor is: {np.sqrt(xg_mean_error)}')
# Out:
# Mean Squared error is: 707150604.8224728
# Sqrt of Mean Squared eroor is: 26592.303488462087

# %%
final_xg_model.score(x_val,y_val)
# Out:
# 0.8894264599856956

# %% [markdown]
# # Finally training using full data

# %%
final_dataframe.head()
# Out:
#    OverallQual  GrLivArea  GarageArea  ...  2ndFlrSF  OpenPorchSF  LotArea
# 0          7.0     1710.0       548.0  ...     854.0         61.0   8450.0
# 1          6.0     1262.0       460.0  ...       0.0          0.0   9600.0
# 2          7.0     1786.0       608.0  ...     866.0         42.0  11250.0
# 3          7.0     1717.0       642.0  ...     756.0         35.0   9550.0
# 4          8.0     2198.0       836.0  ...    1053.0         84.0  14260.0
#
# [5 rows x 16 columns]

# %%
np.random.seed(149)
final_xg_model.fit(final_dataframe,y)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.7, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=200,
#              n_jobs=1, nthread=None, objective='reg:squarederror',
#              random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#              seed=None, silent=None, subsample=0.5, verbosity=1)

# %% [markdown]
# # Let's Deal with Test Data

# %% [markdown]
# ## Let's get test Dataset

# %%
test_df=pd.read_csv('/content/drive/MyDrive/Kaggle Competition/Regression/House Price/test.csv')
test_df.head()
# Out:
#      Id  MSSubClass MSZoning  ...  YrSold  SaleType SaleCondition
# 0  1461          20       RH  ...    2010        WD        Normal
# 1  1462          20       RL  ...    2010        WD        Normal
# 2  1463          60       RL  ...    2010        WD        Normal
# 3  1464          60       RL  ...    2010        WD        Normal
# 4  1465         120       RL  ...    2010        WD        Normal
#
# [5 rows x 80 columns]

# %%
dup_test_df=test_df.copy()
dup_test_df=dup_test_df.drop('Id',axis=1)
dup_test_df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  ...  YrSold SaleType SaleCondition
# 0          20       RH         80.0  ...    2010       WD        Normal
# 1          20       RL         81.0  ...    2010       WD        Normal
# 2          60       RL         74.0  ...    2010       WD        Normal
# 3          60       RL         78.0  ...    2010       WD        Normal
# 4         120       RL         43.0  ...    2010       WD        Normal
#
# [5 rows x 79 columns]

# %%
plt.figure(figsize=(20,10))
dup_test_df.isna().sum().sort_values(ascending=False).plot(kind='bar')
plt.tight_layout();

# %% [markdown]
# ## Filling missing values in test dataset

# %%
def filling_missing_values(df):
  categorical_column=[]
  na_columns=df.isna().sum()

  for column_name,column_value in df.items():
    if pd.api.types.is_string_dtype(column_value):
      categorical_column.append(column_name)

  for k,v in na_columns.items():
    if (k in categorical_column) & (v>0):
      df[k]=df[k].fillna('no')
  
  for column_name,column_value in df.items():
    if pd.api.types.is_string_dtype(column_value):
      df[column_name]=column_value.astype('category').cat.as_ordered()

  for column_name,column_values in df.items():
    if not pd.api.types.is_numeric_dtype(column_values):
      df[column_name]=pd.Categorical(column_values).codes+1
  

  x=pd.DataFrame(imputer.transform(df),columns=df.columns)

  final=pd.DataFrame()
  for i in best_feature:
    final[best_feature]=x[best_feature]

  return final

# %%
x_test=filling_missing_values(dup_test_df)
x_test.head()
# Out:
#    OverallQual  GrLivArea  GarageArea  ...  2ndFlrSF  OpenPorchSF  LotArea
# 0          5.0      896.0       730.0  ...       0.0          0.0  11622.0
# 1          6.0     1329.0       312.0  ...       0.0         36.0  14267.0
# 2          5.0     1629.0       482.0  ...     701.0         34.0  13830.0
# 3          6.0     1604.0       470.0  ...     678.0         36.0   9978.0
# 4          8.0     1280.0       506.0  ...       0.0         82.0   5005.0
#
# [5 rows x 16 columns]

# %% [markdown]
# ## Predicting the output using XGBoostRegressor model with best parameters

# %%
y_pred=final_xg_model.predict(x_test)
y_pred
# Out:
# array([126787.03, 166099.06, 185660.03, ..., 186981.39, 125210.48,
#        232226.05], dtype=float32)

# %% [markdown]
# ## Final submission Dataframe

# %%
submission = pd.DataFrame({'Id':test_df['Id'],'SalePrice':y_pred})

# %%
submission.head()
# Out:
#      Id      SalePrice
# 0  1461  126787.031250
# 1  1462  166099.062500
# 2  1463  185660.031250
# 3  1464  183821.828125
# 4  1465  193133.484375

# %% [markdown]
# ## Final Submission in the format of csv file

# %%
submission.to_csv("/content/drive/MyDrive/Kaggle Competition/Regression/House Price/submission_file.csv",index=False)

# %% [markdown]
# Finally got into top 63% :) :) in Kaggle Competition
